# %%
import tensorflow as tf

from keras.layers import Conv2D, AveragePooling2D, BatchNormalization, Input, Dense, Flatten, ZeroPadding2D, MaxPooling2D
from keras.callbacks import EarlyStopping
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import Model
from keras.layers.advanced_activations import ReLU
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import Add
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.preprocessing import image

# %%
# Config variables
# Data images are not of the same size
INPUT_SIZE = [224, 224]
BATCH = 16

# %%
# No data augmentation
train_val_image_data_generator = ImageDataGenerator(rescale=1.0/255,
                                            rotation_range=20,
                                            zoom_range=0.2,
                                            width_shift_range=0.2,
                                            height_shift_range=0.2,
                                            shear_range=0.2,
                                            horizontal_flip=True,
                                            fill_mode="nearest",
                                            validation_split=0.2
                                            )

train_data = train_val_image_data_generator.flow_from_directory('./data/',
                                                     target_size = INPUT_SIZE,
                                                     batch_size=BATCH,
                                                     subset='training',
                                                     shuffle=True,
                                                     classes=['with_mask','without_mask']
                                                     )
validate_data = train_val_image_data_generator.flow_from_directory('./data/',
                                                     target_size = INPUT_SIZE,
                                                     batch_size=BATCH,
                                                     subset='validation',
                                                     shuffle=True,
                                                     classes=['with_mask','without_mask']
                                                     )
# Out:
# Found 6043 images belonging to 2 classes.
# Found 1510 images belonging to 2 classes.

# %%
def identity_block(resnet50_layer_result, num_filter1, num_filter2):
    resnet50_layer_result_skip = resnet50_layer_result

    resnet50_layer_result = Conv2D(num_filter1, kernel_size=(1, 1), strides=(1, 1), padding='valid', kernel_regularizer=l2(0.001))(resnet50_layer_result)
    resnet50_layer_result = BatchNormalization()(resnet50_layer_result)
    resnet50_layer_result = ReLU()(resnet50_layer_result)

    resnet50_layer_result = Conv2D(num_filter1, kernel_size=(3, 3), strides=(1, 1), padding='same', kernel_regularizer=l2(0.001))(resnet50_layer_result)
    resnet50_layer_result = BatchNormalization()(resnet50_layer_result)
    resnet50_layer_result = ReLU()(resnet50_layer_result)

    resnet50_layer_result = Conv2D(num_filter2, kernel_size=(1, 1), strides=(1, 1), padding='valid', kernel_regularizer=l2(0.001))(resnet50_layer_result)
    resnet50_layer_result = BatchNormalization()(resnet50_layer_result)

    resnet50_layer_result = Add()([resnet50_layer_result, resnet50_layer_result_skip])
    resnet50_layer_result = ReLU()(resnet50_layer_result)

    return resnet50_layer_result

def conv_block(resnet50_layer_result, strides, num_filter1, num_filter2):
    resnet50_layer_result_skip = resnet50_layer_result

    resnet50_layer_result = Conv2D(num_filter1, kernel_size=(1, 1), strides=strides, padding='valid', kernel_regularizer=l2(0.001))(resnet50_layer_result)
    resnet50_layer_result = BatchNormalization()(resnet50_layer_result)
    resnet50_layer_result = ReLU()(resnet50_layer_result)

    resnet50_layer_result = Conv2D(num_filter1, kernel_size=(3, 3), strides=(1, 1), padding='same', kernel_regularizer=l2(0.001))(resnet50_layer_result)
    resnet50_layer_result = BatchNormalization()(resnet50_layer_result)
    resnet50_layer_result = ReLU()(resnet50_layer_result)

    resnet50_layer_result = Conv2D(num_filter2, kernel_size=(1, 1), strides=(1, 1), padding='valid', kernel_regularizer=l2(0.001))(resnet50_layer_result)
    resnet50_layer_result = BatchNormalization()(resnet50_layer_result)

    resnet50_layer_result_skip = Conv2D(num_filter2, kernel_size=(1, 1), strides=strides, padding='valid', kernel_regularizer=l2(0.001))(resnet50_layer_result)
    resnet50_layer_result_skip = BatchNormalization()(resnet50_layer_result)

    resnet50_layer_result = Add()([resnet50_layer_result, resnet50_layer_result_skip])
    resnet50_layer_result = ReLU()(resnet50_layer_result)

    return resnet50_layer_result

resnet50_input = Input(shape=INPUT_SIZE + [3])
resnet50_layer_result = ZeroPadding2D(padding=(3, 3))(resnet50_input)

resnet50_layer_result = Conv2D(filters=64, kernel_size=(7, 7), strides=(2, 2))(resnet50_layer_result)
resnet50_layer_result = BatchNormalization()(resnet50_layer_result)
resnet50_layer_result = ReLU()(resnet50_layer_result)
resnet50_layer_result = MaxPooling2D((3, 3), strides=(2, 2))(resnet50_layer_result)

resnet50_layer_result = conv_block(resnet50_layer_result, (1, 1), 64, 256)
resnet50_layer_result = identity_block(resnet50_layer_result, 64, 256)
resnet50_layer_result = identity_block(resnet50_layer_result, 64, 256)

resnet50_layer_result = conv_block(resnet50_layer_result, (2, 2), 128, 512)
resnet50_layer_result = identity_block(resnet50_layer_result, 128, 512)
resnet50_layer_result = identity_block(resnet50_layer_result, 128, 512)
resnet50_layer_result = identity_block(resnet50_layer_result, 128, 512)

resnet50_layer_result = conv_block(resnet50_layer_result, (2, 2), 256, 1024)
resnet50_layer_result = identity_block(resnet50_layer_result, 256, 1024)
resnet50_layer_result = identity_block(resnet50_layer_result, 256, 1024)
resnet50_layer_result = identity_block(resnet50_layer_result, 256, 1024)
resnet50_layer_result = identity_block(resnet50_layer_result, 256, 1024)
resnet50_layer_result = identity_block(resnet50_layer_result, 256, 1024)

resnet50_layer_result = conv_block(resnet50_layer_result, (2, 2), 512, 2048)
resnet50_layer_result = identity_block(resnet50_layer_result, 512, 2048)
resnet50_layer_result = identity_block(resnet50_layer_result, 512, 2048)

resnet50_layer_result = AveragePooling2D((2, 2), padding='same')(resnet50_layer_result)
resnet50_layer_result = Flatten()(resnet50_layer_result)
resnet50_layer_result = Dense(units=2, activation='softmax', kernel_initializer='he_normal')(resnet50_layer_result)

resnet50 = Model(inputs=resnet50_input, outputs=resnet50_layer_result)
resnet50.summary()
# Out:
# Model: "model_14"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_15 (InputLayer)           [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# zero_padding2d_14 (ZeroPadding2 (None, 230, 230, 3)  0           input_15[0][0]
# __________________________________________________________________________________________________
# conv2d_761 (Conv2D)             (None, 112, 112, 64) 9472        zero_padding2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_761 (BatchN (None, 112, 112, 64) 256         conv2d_761[0][0]
# __________________________________________________________________________________________________
# re_lu_689 (ReLU)                (None, 112, 112, 64) 0           batch_normalization_761[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_14 (MaxPooling2D) (None, 55, 55, 64)   0           re_lu_689[0][0]
# __________________________________________________________________________________________________
# conv2d_762 (Conv2D)             (None, 55, 55, 64)   4160        max_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_762 (BatchN (None, 55, 55, 64)   256         conv2d_762[0][0]
# __________________________________________________________________________________________________
# re_lu_690 (ReLU)                (None, 55, 55, 64)   0           batch_normalization_762[0][0]
# __________________________________________________________________________________________________
# conv2d_763 (Conv2D)             (None, 55, 55, 64)   36928       re_lu_690[0][0]
# __________________________________________________________________________________________________
# batch_normalization_763 (BatchN (None, 55, 55, 64)   256         conv2d_763[0][0]
# __________________________________________________________________________________________________
# re_lu_691 (ReLU)                (None, 55, 55, 64)   0           batch_normalization_763[0][0]
# __________________________________________________________________________________________________
# conv2d_764 (Conv2D)             (None, 55, 55, 256)  16640       re_lu_691[0][0]
# __________________________________________________________________________________________________
# batch_normalization_764 (BatchN (None, 55, 55, 256)  1024        conv2d_764[0][0]
# __________________________________________________________________________________________________
# batch_normalization_765 (BatchN (None, 55, 55, 256)  1024        batch_normalization_764[0][0]
# __________________________________________________________________________________________________
# add_225 (Add)                   (None, 55, 55, 256)  0           batch_normalization_764[0][0]
#                                                                  batch_normalization_765[0][0]
# __________________________________________________________________________________________________
# re_lu_692 (ReLU)                (None, 55, 55, 256)  0           add_225[0][0]
# __________________________________________________________________________________________________
# conv2d_766 (Conv2D)             (None, 55, 55, 64)   16448       re_lu_692[0][0]
# __________________________________________________________________________________________________
# batch_normalization_766 (BatchN (None, 55, 55, 64)   256         conv2d_766[0][0]
# __________________________________________________________________________________________________
# re_lu_693 (ReLU)                (None, 55, 55, 64)   0           batch_normalization_766[0][0]
# __________________________________________________________________________________________________
# conv2d_767 (Conv2D)             (None, 55, 55, 64)   36928       re_lu_693[0][0]
# __________________________________________________________________________________________________
# batch_normalization_767 (BatchN (None, 55, 55, 64)   256         conv2d_767[0][0]
# __________________________________________________________________________________________________
# re_lu_694 (ReLU)                (None, 55, 55, 64)   0           batch_normalization_767[0][0]
# __________________________________________________________________________________________________
# conv2d_768 (Conv2D)             (None, 55, 55, 256)  16640       re_lu_694[0][0]
# __________________________________________________________________________________________________
# batch_normalization_768 (BatchN (None, 55, 55, 256)  1024        conv2d_768[0][0]
# __________________________________________________________________________________________________
# add_226 (Add)                   (None, 55, 55, 256)  0           batch_normalization_768[0][0]
#                                                                  re_lu_692[0][0]
# __________________________________________________________________________________________________
# re_lu_695 (ReLU)                (None, 55, 55, 256)  0           add_226[0][0]
# __________________________________________________________________________________________________
# conv2d_769 (Conv2D)             (None, 55, 55, 64)   16448       re_lu_695[0][0]
# __________________________________________________________________________________________________
# batch_normalization_769 (BatchN (None, 55, 55, 64)   256         conv2d_769[0][0]
# __________________________________________________________________________________________________
# re_lu_696 (ReLU)                (None, 55, 55, 64)   0           batch_normalization_769[0][0]
# __________________________________________________________________________________________________
# conv2d_770 (Conv2D)             (None, 55, 55, 64)   36928       re_lu_696[0][0]
# __________________________________________________________________________________________________
# batch_normalization_770 (BatchN (None, 55, 55, 64)   256         conv2d_770[0][0]
# __________________________________________________________________________________________________
# re_lu_697 (ReLU)                (None, 55, 55, 64)   0           batch_normalization_770[0][0]
# __________________________________________________________________________________________________
# conv2d_771 (Conv2D)             (None, 55, 55, 256)  16640       re_lu_697[0][0]
# __________________________________________________________________________________________________
# batch_normalization_771 (BatchN (None, 55, 55, 256)  1024        conv2d_771[0][0]
# __________________________________________________________________________________________________
# add_227 (Add)                   (None, 55, 55, 256)  0           batch_normalization_771[0][0]
#                                                                  re_lu_695[0][0]
# __________________________________________________________________________________________________
# re_lu_698 (ReLU)                (None, 55, 55, 256)  0           add_227[0][0]
# __________________________________________________________________________________________________
# conv2d_772 (Conv2D)             (None, 28, 28, 128)  32896       re_lu_698[0][0]
# __________________________________________________________________________________________________
# batch_normalization_772 (BatchN (None, 28, 28, 128)  512         conv2d_772[0][0]
# __________________________________________________________________________________________________
# re_lu_699 (ReLU)                (None, 28, 28, 128)  0           batch_normalization_772[0][0]
# __________________________________________________________________________________________________
# conv2d_773 (Conv2D)             (None, 28, 28, 128)  147584      re_lu_699[0][0]
# __________________________________________________________________________________________________
# batch_normalization_773 (BatchN (None, 28, 28, 128)  512         conv2d_773[0][0]
# __________________________________________________________________________________________________
# re_lu_700 (ReLU)                (None, 28, 28, 128)  0           batch_normalization_773[0][0]
# __________________________________________________________________________________________________
# conv2d_774 (Conv2D)             (None, 28, 28, 512)  66048       re_lu_700[0][0]
# __________________________________________________________________________________________________
# batch_normalization_774 (BatchN (None, 28, 28, 512)  2048        conv2d_774[0][0]
# __________________________________________________________________________________________________
# batch_normalization_775 (BatchN (None, 28, 28, 512)  2048        batch_normalization_774[0][0]
# __________________________________________________________________________________________________
# add_228 (Add)                   (None, 28, 28, 512)  0           batch_normalization_774[0][0]
#                                                                  batch_normalization_775[0][0]
# __________________________________________________________________________________________________
# re_lu_701 (ReLU)                (None, 28, 28, 512)  0           add_228[0][0]
# __________________________________________________________________________________________________
# conv2d_776 (Conv2D)             (None, 28, 28, 128)  65664       re_lu_701[0][0]
# __________________________________________________________________________________________________
# batch_normalization_776 (BatchN (None, 28, 28, 128)  512         conv2d_776[0][0]
# __________________________________________________________________________________________________
# re_lu_702 (ReLU)                (None, 28, 28, 128)  0           batch_normalization_776[0][0]
# __________________________________________________________________________________________________
# conv2d_777 (Conv2D)             (None, 28, 28, 128)  147584      re_lu_702[0][0]
# __________________________________________________________________________________________________
# batch_normalization_777 (BatchN (None, 28, 28, 128)  512         conv2d_777[0][0]
# __________________________________________________________________________________________________
# re_lu_703 (ReLU)                (None, 28, 28, 128)  0           batch_normalization_777[0][0]
# __________________________________________________________________________________________________
# conv2d_778 (Conv2D)             (None, 28, 28, 512)  66048       re_lu_703[0][0]
# __________________________________________________________________________________________________
# batch_normalization_778 (BatchN (None, 28, 28, 512)  2048        conv2d_778[0][0]
# __________________________________________________________________________________________________
# add_229 (Add)                   (None, 28, 28, 512)  0           batch_normalization_778[0][0]
#                                                                  re_lu_701[0][0]
# __________________________________________________________________________________________________
# re_lu_704 (ReLU)                (None, 28, 28, 512)  0           add_229[0][0]
# __________________________________________________________________________________________________
# conv2d_779 (Conv2D)             (None, 28, 28, 128)  65664       re_lu_704[0][0]
# __________________________________________________________________________________________________
# batch_normalization_779 (BatchN (None, 28, 28, 128)  512         conv2d_779[0][0]
# __________________________________________________________________________________________________
# re_lu_705 (ReLU)                (None, 28, 28, 128)  0           batch_normalization_779[0][0]
# __________________________________________________________________________________________________
# conv2d_780 (Conv2D)             (None, 28, 28, 128)  147584      re_lu_705[0][0]
# __________________________________________________________________________________________________
# batch_normalization_780 (BatchN (None, 28, 28, 128)  512         conv2d_780[0][0]
# __________________________________________________________________________________________________
# re_lu_706 (ReLU)                (None, 28, 28, 128)  0           batch_normalization_780[0][0]
# __________________________________________________________________________________________________
# conv2d_781 (Conv2D)             (None, 28, 28, 512)  66048       re_lu_706[0][0]
# __________________________________________________________________________________________________
# batch_normalization_781 (BatchN (None, 28, 28, 512)  2048        conv2d_781[0][0]
# __________________________________________________________________________________________________
# add_230 (Add)                   (None, 28, 28, 512)  0           batch_normalization_781[0][0]
#                                                                  re_lu_704[0][0]
# __________________________________________________________________________________________________
# re_lu_707 (ReLU)                (None, 28, 28, 512)  0           add_230[0][0]
# __________________________________________________________________________________________________
# conv2d_782 (Conv2D)             (None, 28, 28, 128)  65664       re_lu_707[0][0]
# __________________________________________________________________________________________________
# batch_normalization_782 (BatchN (None, 28, 28, 128)  512         conv2d_782[0][0]
# __________________________________________________________________________________________________
# re_lu_708 (ReLU)                (None, 28, 28, 128)  0           batch_normalization_782[0][0]
# __________________________________________________________________________________________________
# conv2d_783 (Conv2D)             (None, 28, 28, 128)  147584      re_lu_708[0][0]
# __________________________________________________________________________________________________
# batch_normalization_783 (BatchN (None, 28, 28, 128)  512         conv2d_783[0][0]
# __________________________________________________________________________________________________
# re_lu_709 (ReLU)                (None, 28, 28, 128)  0           batch_normalization_783[0][0]
# __________________________________________________________________________________________________
# conv2d_784 (Conv2D)             (None, 28, 28, 512)  66048       re_lu_709[0][0]
# __________________________________________________________________________________________________
# batch_normalization_784 (BatchN (None, 28, 28, 512)  2048        conv2d_784[0][0]
# __________________________________________________________________________________________________
# add_231 (Add)                   (None, 28, 28, 512)  0           batch_normalization_784[0][0]
#                                                                  re_lu_707[0][0]
# __________________________________________________________________________________________________
# re_lu_710 (ReLU)                (None, 28, 28, 512)  0           add_231[0][0]
# __________________________________________________________________________________________________
# conv2d_785 (Conv2D)             (None, 14, 14, 256)  131328      re_lu_710[0][0]
# __________________________________________________________________________________________________
# batch_normalization_785 (BatchN (None, 14, 14, 256)  1024        conv2d_785[0][0]
# __________________________________________________________________________________________________
# re_lu_711 (ReLU)                (None, 14, 14, 256)  0           batch_normalization_785[0][0]
# __________________________________________________________________________________________________
# conv2d_786 (Conv2D)             (None, 14, 14, 256)  590080      re_lu_711[0][0]
# __________________________________________________________________________________________________
# batch_normalization_786 (BatchN (None, 14, 14, 256)  1024        conv2d_786[0][0]
# __________________________________________________________________________________________________
# re_lu_712 (ReLU)                (None, 14, 14, 256)  0           batch_normalization_786[0][0]
# __________________________________________________________________________________________________
# conv2d_787 (Conv2D)             (None, 14, 14, 1024) 263168      re_lu_712[0][0]
# __________________________________________________________________________________________________
# batch_normalization_787 (BatchN (None, 14, 14, 1024) 4096        conv2d_787[0][0]
# __________________________________________________________________________________________________
# batch_normalization_788 (BatchN (None, 14, 14, 1024) 4096        batch_normalization_787[0][0]
# __________________________________________________________________________________________________
# add_232 (Add)                   (None, 14, 14, 1024) 0           batch_normalization_787[0][0]
#                                                                  batch_normalization_788[0][0]
# __________________________________________________________________________________________________
# re_lu_713 (ReLU)                (None, 14, 14, 1024) 0           add_232[0][0]
# __________________________________________________________________________________________________
# conv2d_789 (Conv2D)             (None, 14, 14, 256)  262400      re_lu_713[0][0]
# __________________________________________________________________________________________________
# batch_normalization_789 (BatchN (None, 14, 14, 256)  1024        conv2d_789[0][0]
# __________________________________________________________________________________________________
# re_lu_714 (ReLU)                (None, 14, 14, 256)  0           batch_normalization_789[0][0]
# __________________________________________________________________________________________________
# conv2d_790 (Conv2D)             (None, 14, 14, 256)  590080      re_lu_714[0][0]
# __________________________________________________________________________________________________
# batch_normalization_790 (BatchN (None, 14, 14, 256)  1024        conv2d_790[0][0]
# __________________________________________________________________________________________________
# re_lu_715 (ReLU)                (None, 14, 14, 256)  0           batch_normalization_790[0][0]
# __________________________________________________________________________________________________
# conv2d_791 (Conv2D)             (None, 14, 14, 1024) 263168      re_lu_715[0][0]
# __________________________________________________________________________________________________
# batch_normalization_791 (BatchN (None, 14, 14, 1024) 4096        conv2d_791[0][0]
# __________________________________________________________________________________________________
# add_233 (Add)                   (None, 14, 14, 1024) 0           batch_normalization_791[0][0]
#                                                                  re_lu_713[0][0]
# __________________________________________________________________________________________________
# re_lu_716 (ReLU)                (None, 14, 14, 1024) 0           add_233[0][0]
# __________________________________________________________________________________________________
# conv2d_792 (Conv2D)             (None, 14, 14, 256)  262400      re_lu_716[0][0]
# __________________________________________________________________________________________________
# batch_normalization_792 (BatchN (None, 14, 14, 256)  1024        conv2d_792[0][0]
# __________________________________________________________________________________________________
# re_lu_717 (ReLU)                (None, 14, 14, 256)  0           batch_normalization_792[0][0]
# __________________________________________________________________________________________________
# conv2d_793 (Conv2D)             (None, 14, 14, 256)  590080      re_lu_717[0][0]
# __________________________________________________________________________________________________
# batch_normalization_793 (BatchN (None, 14, 14, 256)  1024        conv2d_793[0][0]
# __________________________________________________________________________________________________
# re_lu_718 (ReLU)                (None, 14, 14, 256)  0           batch_normalization_793[0][0]
# __________________________________________________________________________________________________
# conv2d_794 (Conv2D)             (None, 14, 14, 1024) 263168      re_lu_718[0][0]
# __________________________________________________________________________________________________
# batch_normalization_794 (BatchN (None, 14, 14, 1024) 4096        conv2d_794[0][0]
# __________________________________________________________________________________________________
# add_234 (Add)                   (None, 14, 14, 1024) 0           batch_normalization_794[0][0]
#                                                                  re_lu_716[0][0]
# __________________________________________________________________________________________________
# re_lu_719 (ReLU)                (None, 14, 14, 1024) 0           add_234[0][0]
# __________________________________________________________________________________________________
# conv2d_795 (Conv2D)             (None, 14, 14, 256)  262400      re_lu_719[0][0]
# __________________________________________________________________________________________________
# batch_normalization_795 (BatchN (None, 14, 14, 256)  1024        conv2d_795[0][0]
# __________________________________________________________________________________________________
# re_lu_720 (ReLU)                (None, 14, 14, 256)  0           batch_normalization_795[0][0]
# __________________________________________________________________________________________________
# conv2d_796 (Conv2D)             (None, 14, 14, 256)  590080      re_lu_720[0][0]
# __________________________________________________________________________________________________
# batch_normalization_796 (BatchN (None, 14, 14, 256)  1024        conv2d_796[0][0]
# __________________________________________________________________________________________________
# re_lu_721 (ReLU)                (None, 14, 14, 256)  0           batch_normalization_796[0][0]
# __________________________________________________________________________________________________
# conv2d_797 (Conv2D)             (None, 14, 14, 1024) 263168      re_lu_721[0][0]
# __________________________________________________________________________________________________
# batch_normalization_797 (BatchN (None, 14, 14, 1024) 4096        conv2d_797[0][0]
# __________________________________________________________________________________________________
# add_235 (Add)                   (None, 14, 14, 1024) 0           batch_normalization_797[0][0]
#                                                                  re_lu_719[0][0]
# __________________________________________________________________________________________________
# re_lu_722 (ReLU)                (None, 14, 14, 1024) 0           add_235[0][0]
# __________________________________________________________________________________________________
# conv2d_798 (Conv2D)             (None, 14, 14, 256)  262400      re_lu_722[0][0]
# __________________________________________________________________________________________________
# batch_normalization_798 (BatchN (None, 14, 14, 256)  1024        conv2d_798[0][0]
# __________________________________________________________________________________________________
# re_lu_723 (ReLU)                (None, 14, 14, 256)  0           batch_normalization_798[0][0]
# __________________________________________________________________________________________________
# conv2d_799 (Conv2D)             (None, 14, 14, 256)  590080      re_lu_723[0][0]
# __________________________________________________________________________________________________
# batch_normalization_799 (BatchN (None, 14, 14, 256)  1024        conv2d_799[0][0]
# __________________________________________________________________________________________________
# re_lu_724 (ReLU)                (None, 14, 14, 256)  0           batch_normalization_799[0][0]
# __________________________________________________________________________________________________
# conv2d_800 (Conv2D)             (None, 14, 14, 1024) 263168      re_lu_724[0][0]
# __________________________________________________________________________________________________
# batch_normalization_800 (BatchN (None, 14, 14, 1024) 4096        conv2d_800[0][0]
# __________________________________________________________________________________________________
# add_236 (Add)                   (None, 14, 14, 1024) 0           batch_normalization_800[0][0]
#                                                                  re_lu_722[0][0]
# __________________________________________________________________________________________________
# re_lu_725 (ReLU)                (None, 14, 14, 1024) 0           add_236[0][0]
# __________________________________________________________________________________________________
# conv2d_801 (Conv2D)             (None, 14, 14, 256)  262400      re_lu_725[0][0]
# __________________________________________________________________________________________________
# batch_normalization_801 (BatchN (None, 14, 14, 256)  1024        conv2d_801[0][0]
# __________________________________________________________________________________________________
# re_lu_726 (ReLU)                (None, 14, 14, 256)  0           batch_normalization_801[0][0]
# __________________________________________________________________________________________________
# conv2d_802 (Conv2D)             (None, 14, 14, 256)  590080      re_lu_726[0][0]
# __________________________________________________________________________________________________
# batch_normalization_802 (BatchN (None, 14, 14, 256)  1024        conv2d_802[0][0]
# __________________________________________________________________________________________________
# re_lu_727 (ReLU)                (None, 14, 14, 256)  0           batch_normalization_802[0][0]
# __________________________________________________________________________________________________
# conv2d_803 (Conv2D)             (None, 14, 14, 1024) 263168      re_lu_727[0][0]
# __________________________________________________________________________________________________
# batch_normalization_803 (BatchN (None, 14, 14, 1024) 4096        conv2d_803[0][0]
# __________________________________________________________________________________________________
# add_237 (Add)                   (None, 14, 14, 1024) 0           batch_normalization_803[0][0]
#                                                                  re_lu_725[0][0]
# __________________________________________________________________________________________________
# re_lu_728 (ReLU)                (None, 14, 14, 1024) 0           add_237[0][0]
# __________________________________________________________________________________________________
# conv2d_804 (Conv2D)             (None, 7, 7, 512)    524800      re_lu_728[0][0]
# __________________________________________________________________________________________________
# batch_normalization_804 (BatchN (None, 7, 7, 512)    2048        conv2d_804[0][0]
# __________________________________________________________________________________________________
# re_lu_729 (ReLU)                (None, 7, 7, 512)    0           batch_normalization_804[0][0]
# __________________________________________________________________________________________________
# conv2d_805 (Conv2D)             (None, 7, 7, 512)    2359808     re_lu_729[0][0]
# __________________________________________________________________________________________________
# batch_normalization_805 (BatchN (None, 7, 7, 512)    2048        conv2d_805[0][0]
# __________________________________________________________________________________________________
# re_lu_730 (ReLU)                (None, 7, 7, 512)    0           batch_normalization_805[0][0]
# __________________________________________________________________________________________________
# conv2d_806 (Conv2D)             (None, 7, 7, 2048)   1050624     re_lu_730[0][0]
# __________________________________________________________________________________________________
# batch_normalization_806 (BatchN (None, 7, 7, 2048)   8192        conv2d_806[0][0]
# __________________________________________________________________________________________________
# batch_normalization_807 (BatchN (None, 7, 7, 2048)   8192        batch_normalization_806[0][0]
# __________________________________________________________________________________________________
# add_238 (Add)                   (None, 7, 7, 2048)   0           batch_normalization_806[0][0]
#                                                                  batch_normalization_807[0][0]
# __________________________________________________________________________________________________
# re_lu_731 (ReLU)                (None, 7, 7, 2048)   0           add_238[0][0]
# __________________________________________________________________________________________________
# conv2d_808 (Conv2D)             (None, 7, 7, 512)    1049088     re_lu_731[0][0]
# __________________________________________________________________________________________________
# batch_normalization_808 (BatchN (None, 7, 7, 512)    2048        conv2d_808[0][0]
# __________________________________________________________________________________________________
# re_lu_732 (ReLU)                (None, 7, 7, 512)    0           batch_normalization_808[0][0]
# __________________________________________________________________________________________________
# conv2d_809 (Conv2D)             (None, 7, 7, 512)    2359808     re_lu_732[0][0]
# __________________________________________________________________________________________________
# batch_normalization_809 (BatchN (None, 7, 7, 512)    2048        conv2d_809[0][0]
# __________________________________________________________________________________________________
# re_lu_733 (ReLU)                (None, 7, 7, 512)    0           batch_normalization_809[0][0]
# __________________________________________________________________________________________________
# conv2d_810 (Conv2D)             (None, 7, 7, 2048)   1050624     re_lu_733[0][0]
# __________________________________________________________________________________________________
# batch_normalization_810 (BatchN (None, 7, 7, 2048)   8192        conv2d_810[0][0]
# __________________________________________________________________________________________________
# add_239 (Add)                   (None, 7, 7, 2048)   0           batch_normalization_810[0][0]
#                                                                  re_lu_731[0][0]
# __________________________________________________________________________________________________
# re_lu_734 (ReLU)                (None, 7, 7, 2048)   0           add_239[0][0]
# __________________________________________________________________________________________________
# conv2d_811 (Conv2D)             (None, 7, 7, 512)    1049088     re_lu_734[0][0]
# __________________________________________________________________________________________________
# batch_normalization_811 (BatchN (None, 7, 7, 512)    2048        conv2d_811[0][0]
# __________________________________________________________________________________________________
# re_lu_735 (ReLU)                (None, 7, 7, 512)    0           batch_normalization_811[0][0]
# __________________________________________________________________________________________________
# conv2d_812 (Conv2D)             (None, 7, 7, 512)    2359808     re_lu_735[0][0]
# __________________________________________________________________________________________________
# batch_normalization_812 (BatchN (None, 7, 7, 512)    2048        conv2d_812[0][0]
# __________________________________________________________________________________________________
# re_lu_736 (ReLU)                (None, 7, 7, 512)    0           batch_normalization_812[0][0]
# __________________________________________________________________________________________________
# conv2d_813 (Conv2D)             (None, 7, 7, 2048)   1050624     re_lu_736[0][0]
# __________________________________________________________________________________________________
# batch_normalization_813 (BatchN (None, 7, 7, 2048)   8192        conv2d_813[0][0]
# __________________________________________________________________________________________________
# add_240 (Add)                   (None, 7, 7, 2048)   0           batch_normalization_813[0][0]
#                                                                  re_lu_734[0][0]
# __________________________________________________________________________________________________
# re_lu_737 (ReLU)                (None, 7, 7, 2048)   0           add_240[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_14 (AveragePo (None, 4, 4, 2048)   0           re_lu_737[0][0]
# __________________________________________________________________________________________________
# flatten_14 (Flatten)            (None, 32768)        0           average_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 2)            65538       flatten_14[0][0]
# ==================================================================================================
# Total params: 20,880,514
# Trainable params: 20,827,394
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
precision = tf.keras.metrics.Precision()
recall = tf.keras.metrics.Recall()
resnet50.compile(
  loss='binary_crossentropy',
  optimizer='SGD',
  metrics=['accuracy', precision, recall]
)

es = EarlyStopping(monitor='val_accuracy', patience=20, verbose=1, mode='auto')

resnet50_r = resnet50.fit(
  train_data,
  validation_data=validate_data,
  epochs=25,
  steps_per_epoch=len(train_data),
  validation_steps=len(validate_data),
  callbacks=[es]
)
# Out:
# Epoch 1/25
# Exception ignored in: <function ScopedTFGraph.__del__ at 0x000001B4D70AF4C0>
# Traceback (most recent call last):
#   File "d:\Anaconda\envs\COMP9444\lib\site-packages\tensorflow\python\framework\c_api_util.py", line 58, in __del__
#     self.deleter(self.graph)
# KeyboardInterrupt:
#   7/189 [>.............................] - ETA: 2:48 - loss: 16.3082 - accuracy: 0.5580 - precision_3: 0.5580 - recall_3: 0.5580
