# %%
import tensorflow as tf

from keras.layers import Conv2D, DepthwiseConv2D, AveragePooling2D, BatchNormalization, Input, Dense, Flatten
from keras.callbacks import EarlyStopping
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import Model
from keras.layers.advanced_activations import ReLU
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.preprocessing import image

# %%
# Config variables
# Data images are not of the same size
INPUT_SIZE = [224, 224]
BATCH = 32

# %%
# No data augmentation
train_val_image_data_generator = ImageDataGenerator(rescale=1.0/255,
                                            rotation_range=20,
                                            zoom_range=0.2,
                                            width_shift_range=0.2,
                                            height_shift_range=0.2,
                                            shear_range=0.2,
                                            horizontal_flip=True,
                                            fill_mode="nearest",
                                            validation_split=0.2
                                            )

train_data = train_val_image_data_generator.flow_from_directory('./data/',
                                                     target_size = INPUT_SIZE,
                                                     batch_size=BATCH,
                                                     subset='training',
                                                     shuffle=True,
                                                     classes=['with_mask','without_mask']
                                                     )
validate_data = train_val_image_data_generator.flow_from_directory('./data/',
                                                     target_size = INPUT_SIZE,
                                                     batch_size=BATCH,
                                                     subset='validation',
                                                     shuffle=True,
                                                     classes=['with_mask','without_mask']
                                                     )
# Out:
# Found 6043 images belonging to 2 classes.
# Found 1510 images belonging to 2 classes.

# %%
# MobileNet block
def mobilnet_block (x, filters, strides):
    
    x = DepthwiseConv2D(kernel_size = 3, strides = strides, padding = 'same')(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    
    x = Conv2D(filters = filters, kernel_size = 1, strides = 1)(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    
    return x

#stem of the model
input = Input(shape = (224,224,3))
x = Conv2D(filters = 32, kernel_size = 3, strides = 2, padding = 'same')(input)
x = BatchNormalization()(x)
x = ReLU()(x)

# main part of the model
x = mobilnet_block(x, filters = 64, strides = 1)
x = mobilnet_block(x, filters = 128, strides = 2)
x = mobilnet_block(x, filters = 128, strides = 1)
x = mobilnet_block(x, filters = 256, strides = 2)
x = mobilnet_block(x, filters = 256, strides = 1)
x = mobilnet_block(x, filters = 512, strides = 2)
for _ in range (5):
     x = mobilnet_block(x, filters = 512, strides = 1)
x = mobilnet_block(x, filters = 1024, strides = 2)
x = mobilnet_block(x, filters = 1024, strides = 1)
x = AveragePooling2D (pool_size = 7, strides = 1, data_format='channels_first')(x)
x = Flatten()(x)
output = Dense (units = 2, activation = 'softmax')(x)
mobilenet = Model(inputs=input, outputs=output)
mobilenet.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# conv2d_42 (Conv2D)           (None, 112, 112, 32)      896
# _________________________________________________________________
# batch_normalization_81 (Batc (None, 112, 112, 32)      128
# _________________________________________________________________
# re_lu_81 (ReLU)              (None, 112, 112, 32)      0
# _________________________________________________________________
# depthwise_conv2d_39 (Depthwi (None, 112, 112, 32)      320
# _________________________________________________________________
# batch_normalization_82 (Batc (None, 112, 112, 32)      128
# _________________________________________________________________
# re_lu_82 (ReLU)              (None, 112, 112, 32)      0
# _________________________________________________________________
# conv2d_43 (Conv2D)           (None, 112, 112, 64)      2112
# _________________________________________________________________
# batch_normalization_83 (Batc (None, 112, 112, 64)      256
# _________________________________________________________________
# re_lu_83 (ReLU)              (None, 112, 112, 64)      0
# _________________________________________________________________
# depthwise_conv2d_40 (Depthwi (None, 56, 56, 64)        640
# _________________________________________________________________
# batch_normalization_84 (Batc (None, 56, 56, 64)        256
# _________________________________________________________________
# re_lu_84 (ReLU)              (None, 56, 56, 64)        0
# _________________________________________________________________
# conv2d_44 (Conv2D)           (None, 56, 56, 128)       8320
# _________________________________________________________________
# batch_normalization_85 (Batc (None, 56, 56, 128)       512
# _________________________________________________________________
# re_lu_85 (ReLU)              (None, 56, 56, 128)       0
# _________________________________________________________________
# depthwise_conv2d_41 (Depthwi (None, 56, 56, 128)       1280
# _________________________________________________________________
# batch_normalization_86 (Batc (None, 56, 56, 128)       512
# _________________________________________________________________
# re_lu_86 (ReLU)              (None, 56, 56, 128)       0
# _________________________________________________________________
# conv2d_45 (Conv2D)           (None, 56, 56, 128)       16512
# _________________________________________________________________
# batch_normalization_87 (Batc (None, 56, 56, 128)       512
# _________________________________________________________________
# re_lu_87 (ReLU)              (None, 56, 56, 128)       0
# _________________________________________________________________
# depthwise_conv2d_42 (Depthwi (None, 28, 28, 128)       1280
# _________________________________________________________________
# batch_normalization_88 (Batc (None, 28, 28, 128)       512
# _________________________________________________________________
# re_lu_88 (ReLU)              (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_46 (Conv2D)           (None, 28, 28, 256)       33024
# _________________________________________________________________
# batch_normalization_89 (Batc (None, 28, 28, 256)       1024
# _________________________________________________________________
# re_lu_89 (ReLU)              (None, 28, 28, 256)       0
# _________________________________________________________________
# depthwise_conv2d_43 (Depthwi (None, 28, 28, 256)       2560
# _________________________________________________________________
# batch_normalization_90 (Batc (None, 28, 28, 256)       1024
# _________________________________________________________________
# re_lu_90 (ReLU)              (None, 28, 28, 256)       0
# _________________________________________________________________
# conv2d_47 (Conv2D)           (None, 28, 28, 256)       65792
# _________________________________________________________________
# batch_normalization_91 (Batc (None, 28, 28, 256)       1024
# _________________________________________________________________
# re_lu_91 (ReLU)              (None, 28, 28, 256)       0
# _________________________________________________________________
# depthwise_conv2d_44 (Depthwi (None, 14, 14, 256)       2560
# _________________________________________________________________
# batch_normalization_92 (Batc (None, 14, 14, 256)       1024
# _________________________________________________________________
# re_lu_92 (ReLU)              (None, 14, 14, 256)       0
# _________________________________________________________________
# conv2d_48 (Conv2D)           (None, 14, 14, 512)       131584
# _________________________________________________________________
# batch_normalization_93 (Batc (None, 14, 14, 512)       2048
# _________________________________________________________________
# re_lu_93 (ReLU)              (None, 14, 14, 512)       0
# _________________________________________________________________
# depthwise_conv2d_45 (Depthwi (None, 14, 14, 512)       5120
# _________________________________________________________________
# batch_normalization_94 (Batc (None, 14, 14, 512)       2048
# _________________________________________________________________
# re_lu_94 (ReLU)              (None, 14, 14, 512)       0
# _________________________________________________________________
# conv2d_49 (Conv2D)           (None, 14, 14, 512)       262656
# _________________________________________________________________
# batch_normalization_95 (Batc (None, 14, 14, 512)       2048
# _________________________________________________________________
# re_lu_95 (ReLU)              (None, 14, 14, 512)       0
# _________________________________________________________________
# depthwise_conv2d_46 (Depthwi (None, 14, 14, 512)       5120
# _________________________________________________________________
# batch_normalization_96 (Batc (None, 14, 14, 512)       2048
# _________________________________________________________________
# re_lu_96 (ReLU)              (None, 14, 14, 512)       0
# _________________________________________________________________
# conv2d_50 (Conv2D)           (None, 14, 14, 512)       262656
# _________________________________________________________________
# batch_normalization_97 (Batc (None, 14, 14, 512)       2048
# _________________________________________________________________
# re_lu_97 (ReLU)              (None, 14, 14, 512)       0
# _________________________________________________________________
# depthwise_conv2d_47 (Depthwi (None, 14, 14, 512)       5120
# _________________________________________________________________
# batch_normalization_98 (Batc (None, 14, 14, 512)       2048
# _________________________________________________________________
# re_lu_98 (ReLU)              (None, 14, 14, 512)       0
# _________________________________________________________________
# conv2d_51 (Conv2D)           (None, 14, 14, 512)       262656
# _________________________________________________________________
# batch_normalization_99 (Batc (None, 14, 14, 512)       2048
# _________________________________________________________________
# re_lu_99 (ReLU)              (None, 14, 14, 512)       0
# _________________________________________________________________
# depthwise_conv2d_48 (Depthwi (None, 14, 14, 512)       5120
# _________________________________________________________________
# batch_normalization_100 (Bat (None, 14, 14, 512)       2048
# _________________________________________________________________
# re_lu_100 (ReLU)             (None, 14, 14, 512)       0
# _________________________________________________________________
# conv2d_52 (Conv2D)           (None, 14, 14, 512)       262656
# _________________________________________________________________
# batch_normalization_101 (Bat (None, 14, 14, 512)       2048
# _________________________________________________________________
# re_lu_101 (ReLU)             (None, 14, 14, 512)       0
# _________________________________________________________________
# depthwise_conv2d_49 (Depthwi (None, 14, 14, 512)       5120
# _________________________________________________________________
# batch_normalization_102 (Bat (None, 14, 14, 512)       2048
# _________________________________________________________________
# re_lu_102 (ReLU)             (None, 14, 14, 512)       0
# _________________________________________________________________
# conv2d_53 (Conv2D)           (None, 14, 14, 512)       262656
# _________________________________________________________________
# batch_normalization_103 (Bat (None, 14, 14, 512)       2048
# _________________________________________________________________
# re_lu_103 (ReLU)             (None, 14, 14, 512)       0
# _________________________________________________________________
# depthwise_conv2d_50 (Depthwi (None, 7, 7, 512)         5120
# _________________________________________________________________
# batch_normalization_104 (Bat (None, 7, 7, 512)         2048
# _________________________________________________________________
# re_lu_104 (ReLU)             (None, 7, 7, 512)         0
# _________________________________________________________________
# conv2d_54 (Conv2D)           (None, 7, 7, 1024)        525312
# _________________________________________________________________
# batch_normalization_105 (Bat (None, 7, 7, 1024)        4096
# _________________________________________________________________
# re_lu_105 (ReLU)             (None, 7, 7, 1024)        0
# _________________________________________________________________
# depthwise_conv2d_51 (Depthwi (None, 7, 7, 1024)        10240
# _________________________________________________________________
# batch_normalization_106 (Bat (None, 7, 7, 1024)        4096
# _________________________________________________________________
# re_lu_106 (ReLU)             (None, 7, 7, 1024)        0
# _________________________________________________________________
# conv2d_55 (Conv2D)           (None, 7, 7, 1024)        1049600
# _________________________________________________________________
# batch_normalization_107 (Bat (None, 7, 7, 1024)        4096
# _________________________________________________________________
# re_lu_107 (ReLU)             (None, 7, 7, 1024)        0
# _________________________________________________________________
# average_pooling2d_2 (Average (None, 7, 1, 1018)        0
# _________________________________________________________________
# dense_2 (Dense)              (None, 7, 1, 2)           2038
# =================================================================
# Total params: 3,241,846
# Trainable params: 3,219,958
# Non-trainable params: 21,888
# _________________________________________________________________

# %%
precision = tf.keras.metrics.Precision()
recall = tf.keras.metrics.Recall()
mobilenet.compile(
  loss='binary_crossentropy',
  optimizer='SGD',
  metrics=['accuracy', precision, recall]
)

es = EarlyStopping(monitor='val_accuracy', patience=20, verbose=1, mode='auto')

mobilenet_r = mobilenet.fit(
  train_data,
  validation_data=validate_data,
  epochs=25,
  steps_per_epoch=len(train_data),
  validation_steps=len(validate_data),
  callbacks=[es]
)
# Out:
# Epoch 1/25
# 142/189 [=====================>........] - ETA: 1:27 - loss: 0.7361 - accuracy: 0.5977 - precision: 0.5925 - recall: 0.6388
# d:\Anaconda\envs\COMP9444\lib\site-packages\PIL\Image.py:959: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# 189/189 [==============================] - 356s 2s/step - loss: 0.6867 - accuracy: 0.6335 - precision: 0.6286 - recall: 0.6765 - val_loss: 0.8316 - val_accuracy: 0.5066 - val_precision: 0.5066 - val_recall: 1.0000
# Epoch 2/25
# 189/189 [==============================] - 329s 2s/step - loss: 0.4944 - accuracy: 0.7644 - precision: 0.7599 - recall: 0.7822 - val_loss: 1.0211 - val_accuracy: 0.5066 - val_precision: 0.5066 - val_recall: 1.0000
# Epoch 3/25
# 189/189 [==============================] - 229s 1s/step - loss: 0.3830 - accuracy: 0.8269 - precision: 0.8314 - recall: 0.8260 - val_loss: 1.7143 - val_accuracy: 0.5066 - val_precision: 0.5066 - val_recall: 1.0000
# Epoch 4/25
# 189/189 [==============================] - 174s 910ms/step - loss: 0.3281 - accuracy: 0.8544 - precision: 0.8587 - recall: 0.8531 - val_loss: 0.4838 - val_accuracy: 0.7815 - val_precision: 0.7341 - val_recall: 0.8915
# Epoch 5/25
# 189/189 [==============================] - 58s 308ms/step - loss: 0.2867 - accuracy: 0.8810 - precision: 0.8833 - recall: 0.8818 - val_loss: 0.9885 - val_accuracy: 0.6808 - val_precision: 0.9670 - val_recall: 0.3830
# Epoch 6/25
# 189/189 [==============================] - 58s 308ms/step - loss: 0.2403 - accuracy: 0.8979 - precision: 0.8992 - recall: 0.8994 - val_loss: 0.3935 - val_accuracy: 0.8285 - val_precision: 0.8721 - val_recall: 0.7752
# Epoch 7/25
# 189/189 [==============================] - 59s 309ms/step - loss: 0.2122 - accuracy: 0.9176 - precision: 0.9165 - recall: 0.9213 - val_loss: 0.2570 - val_accuracy: 0.8914 - val_precision: 0.9156 - val_recall: 0.8654
# Epoch 8/25
# 189/189 [==============================] - 58s 306ms/step - loss: 0.2032 - accuracy: 0.9214 - precision: 0.9204 - recall: 0.9249 - val_loss: 0.3326 - val_accuracy: 0.8550 - val_precision: 0.8500 - val_recall: 0.8667
# Epoch 9/25
# 189/189 [==============================] - 57s 303ms/step - loss: 0.1909 - accuracy: 0.9217 - precision: 0.9246 - recall: 0.9207 - val_loss: 0.2272 - val_accuracy: 0.9073 - val_precision: 0.9589 - val_recall: 0.8536
# Epoch 10/25
# 189/189 [==============================] - 59s 313ms/step - loss: 0.1800 - accuracy: 0.9318 - precision: 0.9327 - recall: 0.9327 - val_loss: 0.3122 - val_accuracy: 0.8775 - val_precision: 0.9915 - val_recall: 0.7647
# Epoch 11/25
# 189/189 [==============================] - 62s 329ms/step - loss: 0.1787 - accuracy: 0.9305 - precision: 0.9309 - recall: 0.9321 - val_loss: 0.2318 - val_accuracy: 0.9166 - val_precision: 0.9776 - val_recall: 0.8549
# Epoch 12/25
# 189/189 [==============================] - 61s 320ms/step - loss: 0.1569 - accuracy: 0.9406 - precision: 0.9427 - recall: 0.9399 - val_loss: 0.2358 - val_accuracy: 0.8894 - val_precision: 0.9807 - val_recall: 0.7974
# Epoch 13/25
# 189/189 [==============================] - 59s 314ms/step - loss: 0.1557 - accuracy: 0.9411 - precision: 0.9451 - recall: 0.9383 - val_loss: 0.3179 - val_accuracy: 0.8742 - val_precision: 0.9800 - val_recall: 0.7673
# Epoch 14/25
# 189/189 [==============================] - 59s 310ms/step - loss: 0.1336 - accuracy: 0.9515 - precision: 0.9517 - recall: 0.9527 - val_loss: 0.2097 - val_accuracy: 0.9079 - val_precision: 0.9497 - val_recall: 0.8641
# Epoch 15/25
# 189/189 [==============================] - 63s 331ms/step - loss: 0.1289 - accuracy: 0.9474 - precision: 0.9516 - recall: 0.9442 - val_loss: 0.1712 - val_accuracy: 0.9331 - val_precision: 0.9511 - val_recall: 0.9150
# Epoch 16/25
# 189/189 [==============================] - 65s 345ms/step - loss: 0.1335 - accuracy: 0.9517 - precision: 0.9509 - recall: 0.9540 - val_loss: 0.3153 - val_accuracy: 0.8781 - val_precision: 0.8290 - val_recall: 0.9569
# Epoch 17/25
# 189/189 [==============================] - 63s 334ms/step - loss: 0.1223 - accuracy: 0.9532 - precision: 0.9528 - recall: 0.9549 - val_loss: 0.0989 - val_accuracy: 0.9609 - val_precision: 0.9645 - val_recall: 0.9582
# Epoch 18/25
# 189/189 [==============================] - 70s 372ms/step - loss: 0.1054 - accuracy: 0.9605 - precision: 0.9614 - recall: 0.9605 - val_loss: 0.3985 - val_accuracy: 0.8563 - val_precision: 0.9910 - val_recall: 0.7229
# Epoch 19/25
# 189/189 [==============================] - 59s 310ms/step - loss: 0.1063 - accuracy: 0.9609 - precision: 0.9618 - recall: 0.9611 - val_loss: 0.2222 - val_accuracy: 0.9099 - val_precision: 0.9787 - val_recall: 0.8405
# Epoch 20/25
# 189/189 [==============================] - 61s 325ms/step - loss: 0.0992 - accuracy: 0.9629 - precision: 0.9653 - recall: 0.9615 - val_loss: 0.2572 - val_accuracy: 0.9278 - val_precision: 0.9795 - val_recall: 0.8758
# Epoch 21/25
# 189/189 [==============================] - 62s 329ms/step - loss: 0.1078 - accuracy: 0.9641 - precision: 0.9644 - recall: 0.9647 - val_loss: 0.1874 - val_accuracy: 0.9258 - val_precision: 0.9491 - val_recall: 0.9020
# Epoch 22/25
# 189/189 [==============================] - 61s 321ms/step - loss: 0.0948 - accuracy: 0.9648 - precision: 0.9666 - recall: 0.9638 - val_loss: 0.2496 - val_accuracy: 0.8993 - val_precision: 0.9665 - val_recall: 0.8301
# Epoch 23/25
# 189/189 [==============================] - 70s 367ms/step - loss: 0.1000 - accuracy: 0.9624 - precision: 0.9622 - recall: 0.9638 - val_loss: 0.1290 - val_accuracy: 0.9497 - val_precision: 0.9445 - val_recall: 0.9569
# Epoch 24/25
# 189/189 [==============================] - 67s 355ms/step - loss: 0.0875 - accuracy: 0.9667 - precision: 0.9692 - recall: 0.9651 - val_loss: 0.1387 - val_accuracy: 0.9430 - val_precision: 0.9644 - val_recall: 0.9216
# Epoch 25/25
# 189/189 [==============================] - 58s 309ms/step - loss: 0.0903 - accuracy: 0.9674 - precision: 0.9689 - recall: 0.9667 - val_loss: 0.2355 - val_accuracy: 0.9040 - val_precision: 0.9769 - val_recall: 0.8301
