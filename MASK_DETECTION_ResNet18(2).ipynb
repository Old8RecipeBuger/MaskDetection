# %%
import tensorflow as tf

from keras.layers import Conv2D, AveragePooling2D, BatchNormalization, Input, Dense, Flatten, ZeroPadding2D, MaxPooling2D,Dropout
from keras.callbacks import EarlyStopping
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import Model
from keras.layers.advanced_activations import ReLU
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import Add
import matplotlib.pyplot as plt
import numpy as np

# %%
# Config variables
# Data images are not of the same size
INPUT_SIZE = [224, 224]
BATCH = 16

# %%
# No data augmentation
train_val_image_data_generator = ImageDataGenerator(rescale=1.0/255,
                                            rotation_range=20,
                                            zoom_range=0.2,
                                            width_shift_range=0.2,
                                            height_shift_range=0.2,
                                            shear_range=0.2,
                                            horizontal_flip=True,
                                            fill_mode="nearest",
                                            validation_split=0.2
                                            )

train_data = train_val_image_data_generator.flow_from_directory('./data/',
                                                     target_size = INPUT_SIZE,
                                                     batch_size=BATCH,
                                                     classes=['with_mask','without_mask'],
                                                     subset='training',
                                                     shuffle=True
                                                     )
validate_data = train_val_image_data_generator.flow_from_directory('./data/',
                                                     target_size = INPUT_SIZE,
                                                     batch_size=BATCH,
                                                     classes=['with_mask','without_mask'],
                                                     subset='validation',
                                                     shuffle=True
                                                     )
# Out:
# Found 6043 images belonging to 2 classes.
# Found 1510 images belonging to 2 classes.

# %%
def identity_block(x, filters):
    
    x_skip = x
    f1 = filters

    x = Conv2D(f1, kernel_size=(3, 3), strides=(1, 1), padding='same')(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    x = Conv2D(f1, kernel_size=(3, 3), strides=(1, 1),  padding='same')(x)
    x = BatchNormalization()(x)
    
    x = Add()([x, x_skip])
    x = ReLU()(x)
    return x

def conv_block(x, s, filters):
    x_skip = x
    f1= filters

    x = Conv2D(f1, kernel_size=(3, 3), strides=(s, s), padding='same')(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    x = Conv2D(f1, kernel_size=(3, 3), strides=(1, 1), padding='same')(x)
    x = BatchNormalization()(x)

    x_skip = Conv2D(f1, kernel_size=(1, 1), strides=(s, s), padding='valid')(x_skip)
    x_skip = BatchNormalization()(x_skip)

    x = Add()([x, x_skip])
    x = ReLU()(x)

    return x

input = Input(shape=INPUT_SIZE + [3])
x = ZeroPadding2D(padding=(3, 3))(input)

x = Conv2D(filters=64, kernel_size=(7, 7), strides=(2, 2))(x)
x = BatchNormalization()(x)
x = ReLU()(x)
x = MaxPooling2D((3, 3), strides=(2, 2),padding='same')(x)

x = identity_block(x, filters=(64))
x = identity_block(x, filters=(64))


# 3th stage

x = conv_block(x, s=2, filters=(128))
x = identity_block(x, filters=(128))


# 4th stage

x = conv_block(x, s=2, filters=(256))
x = identity_block(x, filters=(256))


# 5th stage

x = conv_block(x, s=2, filters=(512))
x = identity_block(x, filters=(512))

x = AveragePooling2D()(x)
x = Flatten()(x)
x = Dense(units=2, activation='softmax')(x)

resnet = Model(inputs=input, outputs=x, name = 'Resnet')
resnet.summary()
# Out:
# Model: "Resnet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 230, 230, 3)  0           input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 112, 112, 64) 9472        zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 112, 112, 64) 256         conv2d_20[0][0]
# __________________________________________________________________________________________________
# re_lu_17 (ReLU)                 (None, 112, 112, 64) 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 56, 56, 64)   0           re_lu_17[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 56, 56, 64)   36928       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 56, 56, 64)   256         conv2d_21[0][0]
# __________________________________________________________________________________________________
# re_lu_18 (ReLU)                 (None, 56, 56, 64)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 56, 56, 64)   36928       re_lu_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 56, 56, 64)   256         conv2d_22[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 56, 56, 64)   0           batch_normalization_22[0][0]
#                                                                  max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# re_lu_19 (ReLU)                 (None, 56, 56, 64)   0           add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 56, 56, 64)   36928       re_lu_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 56, 56, 64)   256         conv2d_23[0][0]
# __________________________________________________________________________________________________
# re_lu_20 (ReLU)                 (None, 56, 56, 64)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 56, 56, 64)   36928       re_lu_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 56, 56, 64)   256         conv2d_24[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 56, 56, 64)   0           batch_normalization_24[0][0]
#                                                                  re_lu_19[0][0]
# __________________________________________________________________________________________________
# re_lu_21 (ReLU)                 (None, 56, 56, 64)   0           add_9[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 28, 28, 128)  73856       re_lu_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 28, 28, 128)  512         conv2d_25[0][0]
# __________________________________________________________________________________________________
# re_lu_22 (ReLU)                 (None, 28, 28, 128)  0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 28, 28, 128)  147584      re_lu_22[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 28, 28, 128)  8320        re_lu_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 28, 28, 128)  512         conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 28, 28, 128)  512         conv2d_27[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 28, 28, 128)  0           batch_normalization_26[0][0]
#                                                                  batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# re_lu_23 (ReLU)                 (None, 28, 28, 128)  0           add_10[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 28, 28, 128)  147584      re_lu_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 28, 28, 128)  512         conv2d_28[0][0]
# __________________________________________________________________________________________________
# re_lu_24 (ReLU)                 (None, 28, 28, 128)  0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 28, 28, 128)  147584      re_lu_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 28, 28, 128)  512         conv2d_29[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 28, 28, 128)  0           batch_normalization_29[0][0]
#                                                                  re_lu_23[0][0]
# __________________________________________________________________________________________________
# re_lu_25 (ReLU)                 (None, 28, 28, 128)  0           add_11[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 14, 14, 256)  295168      re_lu_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 14, 14, 256)  1024        conv2d_30[0][0]
# __________________________________________________________________________________________________
# re_lu_26 (ReLU)                 (None, 14, 14, 256)  0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 14, 14, 256)  590080      re_lu_26[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 14, 14, 256)  33024       re_lu_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 14, 14, 256)  1024        conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 14, 14, 256)  1024        conv2d_32[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 14, 14, 256)  0           batch_normalization_31[0][0]
#                                                                  batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# re_lu_27 (ReLU)                 (None, 14, 14, 256)  0           add_12[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 14, 14, 256)  590080      re_lu_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 14, 14, 256)  1024        conv2d_33[0][0]
# __________________________________________________________________________________________________
# re_lu_28 (ReLU)                 (None, 14, 14, 256)  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 14, 14, 256)  590080      re_lu_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 14, 14, 256)  1024        conv2d_34[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 14, 14, 256)  0           batch_normalization_34[0][0]
#                                                                  re_lu_27[0][0]
# __________________________________________________________________________________________________
# re_lu_29 (ReLU)                 (None, 14, 14, 256)  0           add_13[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 7, 7, 512)    1180160     re_lu_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 7, 7, 512)    2048        conv2d_35[0][0]
# __________________________________________________________________________________________________
# re_lu_30 (ReLU)                 (None, 7, 7, 512)    0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 7, 7, 512)    2359808     re_lu_30[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 7, 7, 512)    131584      re_lu_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 7, 7, 512)    2048        conv2d_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 7, 7, 512)    2048        conv2d_37[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 7, 7, 512)    0           batch_normalization_36[0][0]
#                                                                  batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# re_lu_31 (ReLU)                 (None, 7, 7, 512)    0           add_14[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 7, 7, 512)    2359808     re_lu_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 7, 7, 512)    2048        conv2d_38[0][0]
# __________________________________________________________________________________________________
# re_lu_32 (ReLU)                 (None, 7, 7, 512)    0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 7, 7, 512)    2359808     re_lu_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 7, 7, 512)    2048        conv2d_39[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 7, 7, 512)    0           batch_normalization_39[0][0]
#                                                                  re_lu_31[0][0]
# __________________________________________________________________________________________________
# re_lu_33 (ReLU)                 (None, 7, 7, 512)    0           add_15[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 3, 3, 512)    0           re_lu_33[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 4608)         0           average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 2)            9218        flatten_1[0][0]
# ==================================================================================================
# Total params: 11,200,130
# Trainable params: 11,190,530
# Non-trainable params: 9,600
# __________________________________________________________________________________________________

# %%
resnet.compile(optimizer='SGD',loss='binary_crossentropy',metrics=['accuracy'])

es = EarlyStopping(monitor="accuracy", patience=20, verbose=1, mode="auto")

resnet_r = resnet.fit( train_data, validation_data=validate_data,epochs=25, steps_per_epoch=len(train_data),validation_steps=len(validate_data),callbacks=[es])
# Out:
# Epoch 1/25
#   7/378 [..............................] - ETA: 1:02 - loss: 1.8448 - accuracy: 0.5089
# d:\Anaconda\envs\COMP9444\lib\site-packages\PIL\Image.py:959: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# 378/378 [==============================] - 93s 226ms/step - loss: 0.6858 - accuracy: 0.7796 - val_loss: 0.5437 - val_accuracy: 0.7967
# Epoch 2/25
# 378/378 [==============================] - 60s 158ms/step - loss: 0.3970 - accuracy: 0.8492 - val_loss: 0.4138 - val_accuracy: 0.8305
# Epoch 3/25
# 378/378 [==============================] - 62s 163ms/step - loss: 0.3307 - accuracy: 0.8789 - val_loss: 0.2764 - val_accuracy: 0.8967
# Epoch 4/25
# 378/378 [==============================] - 60s 159ms/step - loss: 0.2535 - accuracy: 0.9020 - val_loss: 0.2927 - val_accuracy: 0.8960
# Epoch 5/25
# 378/378 [==============================] - 64s 168ms/step - loss: 0.2380 - accuracy: 0.9123 - val_loss: 0.5884 - val_accuracy: 0.8391
# Epoch 6/25
# 378/378 [==============================] - 60s 160ms/step - loss: 0.1893 - accuracy: 0.9308 - val_loss: 0.8079 - val_accuracy: 0.7344
# Epoch 7/25
# 378/378 [==============================] - 60s 158ms/step - loss: 0.1874 - accuracy: 0.9335 - val_loss: 1.0758 - val_accuracy: 0.7894
# Epoch 8/25
# 378/378 [==============================] - 59s 155ms/step - loss: 0.1589 - accuracy: 0.9409 - val_loss: 0.3961 - val_accuracy: 0.8556
# Epoch 9/25
# 378/378 [==============================] - 60s 158ms/step - loss: 0.1301 - accuracy: 0.9557 - val_loss: 0.2546 - val_accuracy: 0.8947
# Epoch 10/25
# 378/378 [==============================] - 59s 157ms/step - loss: 0.1397 - accuracy: 0.9497 - val_loss: 0.1761 - val_accuracy: 0.9278
# Epoch 11/25
# 378/378 [==============================] - 66s 173ms/step - loss: 0.1242 - accuracy: 0.9575 - val_loss: 0.1603 - val_accuracy: 0.9265
# Epoch 12/25
# 378/378 [==============================] - 63s 166ms/step - loss: 0.1165 - accuracy: 0.9606 - val_loss: 0.1331 - val_accuracy: 0.9536
# Epoch 13/25
# 378/378 [==============================] - 62s 163ms/step - loss: 0.0975 - accuracy: 0.9694 - val_loss: 0.1086 - val_accuracy: 0.9623
# Epoch 14/25
# 154/378 [===========>..................] - ETA: 29s - loss: 0.0929 - accuracy: 0.9704

# %%
plt.plot(resnet_r .history['loss'], label='train loss')
plt.plot(resnet_r .history['val_loss'], label='val loss')
plt.legend()
plt.show()


# plot the accuracy
plt.plot(resnet_r .history['accuracy'], label='train acc')
plt.plot(resnet_r .history['val_accuracy'], label='val acc')
plt.legend()
plt.show()
